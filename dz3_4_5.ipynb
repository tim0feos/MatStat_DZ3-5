}

# %% [markdown]
# ## Метод моментов

# %% [markdown]
# #### Выборочное среднее

# %%
sample_means = {n: [np.round(np.mean(sample), 4) for sample in samples] for n, samples in samples_d.items()}

# %%
# Преобразуем результаты в таблицу для удобства
results_df = pd.DataFrame(sample_means)

# %%
results_df
# Out:
#    5     10     100     200      400      600      800     1000
# 0  41.2  39.2  38.72  40.455  39.0175  38.9100  37.3862  39.230
# 1  36.2  36.5  41.52  39.650  39.0325  38.7883  37.2888  38.739
# 2  57.4  37.0  43.46  39.450  39.4800  39.1933  39.2150  39.135
# 3  57.2  37.1  34.27  37.345  39.6600  38.3550  39.8250  38.840
# 4  34.0  48.9  38.98  39.925  39.5125  39.3700  38.8425  39.231

# %% [markdown]
# #### Оценка параметра

# %%
mm_param = {
    n: [2 * mean - 1 for mean in sample_means[n]]
    for n in samples_d.keys()
}

# %%
# Преобразуем результаты в таблицу для удобства
mm_param_df = pd.DataFrame(mm_param)

# %%
mm_param_df
# Out:
#     5     10     100    200     400      600      800     1000
# 0   81.4  77.4  76.44  79.91  77.035  76.8200  73.7724  77.460
# 1   71.4  72.0  82.04  78.30  77.065  76.5766  73.5776  76.478
# 2  113.8  73.0  85.92  77.90  77.960  77.3866  77.4300  77.270
# 3  113.4  73.2  67.54  73.69  78.320  75.7100  78.6500  76.680
# 4   67.0  96.8  76.96  78.85  78.025  77.7400  76.6850  77.462

# %% [markdown]
# ## Метод максимального правдоподобия

# %%
mmp_param = {
    n: [np.max(sample) for sample in samples]
    for n, samples in samples_d.items()
}

# %%
# Преобразуем в DataFrame для удобства просмотра
mmp_param_df = pd.DataFrame(mmp_param)

# %%
mmp_param_df
# Out:
#    5     10    100   200   400   600   800   1000
# 0    73    77    76    77    77    77    77    77
# 1    72    59    77    77    77    77    77    77
# 2    76    77    77    77    77    77    77    77
# 3    72    74    77    77    77    77    77    77
# 4    48    67    77    77    77    77    77    77

# %% [markdown]
# ## Оптимальная оценка

# %%
# Функция для оценки T(X)
def T(X_n, n):
    numerator = X_n**(n + 1) - (X_n - 1)**(n + 1)
    denominator = X_n**n - (X_n - 1)**n
    return numerator / denominator

# %%
(74**11-73**11)/(74**10-73**10)
# Out:
# 80.86122116679032

# %%
dic = {}  # Пустой словарь

for n, samples in samples_d.items():
    dic[n] = []  # Создаём список для каждой выборки размера n
    i = 0
    for sample in samples:
        m = max(sample)
        l = len(sample)
        #print(n, i, "m=", m, ';', "l=", l)
        dic[n].append([m, l])  # Добавляем данные в список
        i += 1

# %%
# Печатаем все значения в словаре dic
for n, values in dic.items():
    print(f"Размер выборки n={n}:")
    for i, value in enumerate(values):
        print(f"  Выборка {i + 1}: m = {value[0]}; l = {value[1]}")
        m=value[0]
        l=value[1]
        #print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# Размер выборки n=5:
#   Выборка 1: m = 73; l = 5
#   Выборка 2: m = 72; l = 5
#   Выборка 3: m = 76; l = 5
#   Выборка 4: m = 72; l = 5
#   Выборка 5: m = 48; l = 5
# Размер выборки n=10:
#   Выборка 1: m = 77; l = 10
#   Выборка 2: m = 59; l = 10
#   Выборка 3: m = 77; l = 10
#   Выборка 4: m = 74; l = 10
#   Выборка 5: m = 67; l = 10
# Размер выборки n=100:
#   Выборка 1: m = 76; l = 100
#   Выборка 2: m = 77; l = 100
#   Выборка 3: m = 77; l = 100
#   Выборка 4: m = 77; l = 100
#   Выборка 5: m = 77; l = 100
# Размер выборки n=200:
#   Выборка 1: m = 77; l = 200
#   Выборка 2: m = 77; l = 200
#   Выборка 3: m = 77; l = 200
#   Выборка 4: m = 77; l = 200
#   Выборка 5: m = 77; l = 200
# Размер выборки n=400:
#   Выборка 1: m = 77; l = 400
#   Выборка 2: m = 77; l = 400
#   Выборка 3: m = 77; l = 400
#   Выборка 4: m = 77; l = 400
#   Выборка 5: m = 77; l = 400
# Размер выборки n=600:
#   Выборка 1: m = 77; l = 600
#   Выборка 2: m = 77; l = 600
#   Выборка 3: m = 77; l = 600
# ...

# %%
m= 73 ;l= 5
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 87.00551687403302

# %%
m= 72 ; l= 5
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 85.80559402261936

# %%
m= 76 ; l= 5
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 90.6052976879692

# %%
m= 72 ; l= 5
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 85.80559402261936

# %%
m= 48 ; l= 5
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 57.00841974658746

# %%
m= 77 ; l= 10
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 84.16078136643672

# %%
m= 59 ; l= 10
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 64.3640959750814

# %%
m= 77 ; l= 10
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 84.16078136643672

# %%
m= 74 ; l= 10
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 80.86122116679032

# %%
m= 67 ; l= 10
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 73.16240152873986

# %%
m = 76; l = 100
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 76.36226765079539

# %%
m = 77; l = 100
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.37094174618326

# %%
m = 77; l = 200
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.0789936753316

# %%
m = 77; l = 400
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.00538866054005

# %%
m = 77; l = 600
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.00039254614087

# %%
m = 77; l = 800
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.00002872805099

# %%
m = 77; l = 1000
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 77.00000210313922

# %% [markdown]
# ## Задача

# %%
df = pd.read_csv("649.csv", sep=",") #считали данные
df.head() #чтобы видеть, с чем имеем дело
# Out:
#    PRODUCT  DRAW NUMBER  SEQUENCE NUMBER  DRAW DATE  NUMBER DRAWN 1  \
# 0      649            1                0  6/12/1982               3
# 1      649            2                0  6/19/1982               8
# 2      649            3                0  6/26/1982               1
# 3      649            4                0   7/3/1982               3
# 4      649            5                0  7/10/1982               5
#
#    NUMBER DRAWN 2  NUMBER DRAWN 3  NUMBER DRAWN 4  NUMBER DRAWN 5  \
# 0              11              12              14              41
# 1              33              36              37              39
# 2               6              23              24              27
# 3               9              10              13              20
# 4              14              21              31              34
#
#    NUMBER DRAWN 6  BONUS NUMBER
# 0              43            13
# 1              41             9
# 2              39            34
# ...

# %%
# Проверяем, есть ли совпадение в строках
df['MATCH'] = df.apply(
    lambda row: row['BONUS NUMBER'] in [
        row['NUMBER DRAWN 1'],
        row['NUMBER DRAWN 2'],
        row['NUMBER DRAWN 3'],
        row['NUMBER DRAWN 4'],
        row['NUMBER DRAWN 5'],
        row['NUMBER DRAWN 6'],
    ],
    axis=1
)
df #чтобы видеть, с чем имеем дело
# Out:
#       PRODUCT  DRAW NUMBER  SEQUENCE NUMBER  DRAW DATE  NUMBER DRAWN 1  \
# 0         649            1                0  6/12/1982               3
# 1         649            2                0  6/19/1982               8
# 2         649            3                0  6/26/1982               1
# 3         649            4                0   7/3/1982               3
# 4         649            5                0  7/10/1982               5
# ...       ...          ...              ...        ...             ...
# 3660      649         3587                0   6/6/2018              10
# 3661      649         3588                0   6/9/2018              19
# 3662      649         3589                0  6/13/2018               6
# 3663      649         3590                0  6/16/2018               2
# 3664      649         3591                0  6/20/2018              14
#
#       NUMBER DRAWN 2  NUMBER DRAWN 3  NUMBER DRAWN 4  NUMBER DRAWN 5  \
# ...

# %%
matching_rows = df[df['MATCH'] == True].index.tolist()

matching_rows
# Out:
# []

# %%
#df["NUMBER DRAWN 1"].value_counts() # убедимся в равномерности

# %%
#sample = df['BONUS NUMBER'].to_numpy()

# %%
combined_column = df[
    ["NUMBER DRAWN 1", "NUMBER DRAWN 2", "NUMBER DRAWN 3", "NUMBER DRAWN 4", "NUMBER DRAWN 5", "NUMBER DRAWN 6", "BONUS NUMBER"]
].values.flatten()

# Преобразуем в массив
sample = combined_column
# Удаление элементов со значением 0 из массива sample
sample = sample[sample != 0]
#sample = sample[sample < 7]

# %%
# Вычисляем количество вхождений каждого элемента массива sample
unique_elements, counts = np.unique(sample, return_counts=True)

# Создаем словарь для удобства интерпретации
element_counts = dict(zip(unique_elements, counts))

element_counts
# Out:
# {1: 492,
#  2: 493,
#  3: 524,
#  4: 514,
#  5: 522,
#  6: 483,
#  7: 534,
#  8: 520,
#  9: 541,
#  10: 500,
#  11: 509,
#  12: 526,
#  13: 501,
#  14: 471,
#  15: 480,
#  16: 511,
#  17: 511,
#  18: 499,
#  19: 503,
#  20: 544,
#  21: 540,
#  22: 512,
#  23: 532,
#  24: 515,
#  25: 508,
#  26: 525,
#  27: 550,
#  28: 502,
#  29: 504,
#  30: 517,
#  31: 568,
#  32: 519,
#  33: 531,
#  34: 559,
#  35: 497,
#  36: 540,
#  37: 521,
#  38: 540,
#  39: 523,
#  40: 557,
#  41: 540,
#  42: 530,
#  43: 554,
#  44: 529,
#  45: 559,
#  46: 541,
#  47: 559,
#  48: 513,
#  49: 518}

# %%
sample_mean = np.round(np.mean(sample), 2)
sample_mean
# Out:
# 25.31

# %%
sample_variance =np.round(np.mean((np.array(sample) - sample_mean)**2), 2)
sample_variance
# Out:
# 200.09

# %%
mm_assesment = 2*sample_mean - 1
mm_assesment
# Out:
# 49.62

# %%
mmp_assesment = max(sample)
mmp_assesment
# Out:
# 49

# %%
#оптимальная
m = 49
l = 25581
print((m**(l+1)-(m-1)**(l+1))/(m**l-(m-1)**l))
# Out:
# 49.0

# %%
def tdf(
  arguments: list
):
  """
  Функция для вычисления теоретической фунции распределения
  Параметры:
    1. arguments - набор аргументов теоретической фунции распределения
  """
  answer = []
  for elem in arguments:
    if (elem < 1):
      answer.append(0)
    elif (elem >= 1) and (elem <= 49):
      answer.append( int(elem) / 49)
    else:
      answer.append(1)

  return answer

# %%
 def edf(
  arguments: list,
  sample: list
):
  """
  Функция для вычисления эфр
  Параметры:
    1. arguments - набор аргументов эфр
    2. sample - выборка, по которой строится эфр
  """
  return [np.sum( np.array(sample) <= elem )  / len(sample) for elem in arguments]

# %%
x = np.linspace(min(sample)-1, max(sample)+1, 10000)
fig = plt.figure()
plt.plot(x, edf(x, sample), c='red')
plt.plot(x, tdf(x), c='black', ls="--")
plt.grid(True)
plt.legend(['эфр выборки', 'теор. ф.р.'])
plt.show()
#plt.savefig(f'hw3_realData_disc.png', dpi=300)
plt.close(fig)

# %% [markdown]
# ## Колмогоров

# %%
# Параметры
theta = 77  # Максимум дискретного равномерного распределения
Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}  # Критические значения
sizes = samples_d.keys()  # Размеры выборок

# Генерация uniform_samples для корректировки
uniform_samples = {}
for n in sizes:
    np.random.seed(42)  # Для воспроизводимости
    uniform_samples[n] = np.random.uniform(0, 1, (5, n))  # 5 выборок по n элементов с U[0,1]

# Вычисление Ui
work_samples = {}
for n in sizes:
    work_samples[n] = []
    for i in range(5):  # Для каждой выборки
        s = []
        for j in range(len(samples_d[n][i])):
            lim_arg = samples_d[n][i][j] - 1  # F(Xi-) = (Xi - 1) / theta
            s.append(lim_arg / theta + uniform_samples[n][i][j] / theta)  # Ui = F(Xi-) + Yi * (F(Xi) - F(Xi-))
        work_samples[n].append(s)

# Тест Колмогорова для всех выборок
def kolmogorov_test(samples, alpha_values, critical_values):
    all_results = {}
    for size, sample_group in samples.items():
        results = {f"alpha = {alpha}": [] for alpha in alpha_values}
        for sample in sample_group:
            sorted_sample = sorted(sample)
            Dn_p = []
            Dn_m = []
            for k in (np.arange(len(sorted_sample)) + 1):
                F_x = sorted_sample[k-1]  # Теоретическая ФР для Ui равна Ui
                Dn_p.append(np.abs(k / len(sorted_sample) - F_x))
                Dn_m.append(np.abs(F_x - (k - 1) / len(sorted_sample)))
            Dn = max(max(Dn_p), max(Dn_m))

            if len(sorted_sample) >= 20:
                Sn = np.sqrt(len(sorted_sample)) * Dn
            else:
                Sn = (6 * len(sorted_sample) * Dn + 1) / (6 * np.sqrt(len(sorted_sample)))

            for alpha in alpha_values:
                results[f"alpha = {alpha}"].append("H1" if Sn >= critical_values[alpha] else "H0")

        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"{i+1}" for i in range(len(sample_group))])
        all_results[size] = df
        print(f"n = {size}:\n")
        print(df)
        print("\n")
    return all_results

# Запуск теста
alpha_values = [0.1, 0.05, 0.01]
results_tables = kolmogorov_test(work_samples, alpha_values, Kolm_distrib)
# Out:
# n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H1           H0           H0
# 4          H1           H0           H0
# 5          H0           H0           H0
#
#
# n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H1           H0           H0
#
#
# n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H1           H0           H0
# 4          H1           H1           H0
# 5          H0           H0           H0
#
#
# n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# ...

# %% [markdown]
# ## хи -квадрат

# %%
# Данные и параметры
theta = 77  # Максимум дискретного равномерного распределения
sizes = samples_d.keys()  # Размеры выборок
Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}  # Критические значения

# Подготовка таблиц частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = []
    for sample in samples_d[n]:
        freq = Counter(sample)
        # Добавляем отсутствующие значения с частотой 0
        for elem in range(1, theta + 1):
            if elem not in freq:
                freq[elem] = 0
        freq_vector[n].append(freq)

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        for elem in range(1, theta + 1):
            observed_freq = freq_vector[n][i][elem]
            expected_freq = n / theta  # Ожидаемая частота
            stat += (observed_freq - expected_freq) ** 2 / expected_freq
        chi_stats[n].append(stat)

# Границы критических значений для хи-квадрат
critical_values = {alpha: chi2.ppf(1 - alpha, df=theta - 1) for alpha in Kolm_distrib.keys()}

# Результаты теста хи-квадрат
def chi_square_test(chi_stats, critical_values):
    all_results = {}
    for size, stats in chi_stats.items():
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha in critical_values.keys():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical_values[alpha] else "H0")

        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"{i+1}" for i in range(len(stats))])
        all_results[size] = df
        print(f"n = {size}:\n")
        print(df)
        print("\n")
    return all_results

# Проверка промежуточных данных
print("Chi-square statistics for each sample:")
for n, stats in chi_stats.items():
    print(f"n = {n}: {stats}")

print("\nCritical values:")
for alpha, value in critical_values.items():
    print(f"alpha = {alpha}: {value}")

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)
# Out:
# Chi-square statistics for each sample:
# n = 5: [71.99999999999999, 71.99999999999996, 71.99999999999997, 72.0, 72.00000000000016]
# n = 10: [66.99999999999996, 82.3999999999999, 82.39999999999989, 82.3999999999999, 82.39999999999992]
# n = 100: [57.07999999999999, 67.86, 66.32000000000002, 80.18000000000006, 80.18000000000002]
# n = 200: [86.43999999999998, 88.74999999999997, 75.65999999999998, 91.82999999999997, 48.70999999999999]
# n = 400: [89.71999999999998, 62.00000000000004, 62.770000000000024, 72.01000000000005, 82.02000000000002]
# n = 600: [64.25333333333336, 129.4466666666667, 84.78666666666663, 63.226666666666716, 74.77666666666669]
# n = 800: [81.26500000000004, 92.815, 82.99750000000003, 64.71000000000002, 89.15750000000003]
# n = 1000: [73.22600000000001, 112.18799999999999, 77.84600000000002, 73.38, 64.756]
#
# Critical values:
# alpha = 0.1: 92.16616640890501
# alpha = 0.05: 97.35097037903296
# alpha = 0.01: 107.58254478061242
# n = 5:
#
# ...

# %% [markdown]
# ## Колмогоров для сложной гипотезы

# %%
# Параметры выборок
sizes = list(samples_d.keys())  # Преобразуем в список для индексирования

Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}

# Генерация Yi для U[0, 1]
uniform_samples = {}
for n in sizes:
    np.random.seed(42)
    uniform_samples[n] = np.random.rand(5, n)  # 5 выборок по n элементов

# Высчитываем Ui
work_samples = {}

# Маленькие выборки
for n in sizes[:2]:  # Для n = 5, 10
    work_samples[n] = []
    for i in range(5):
        estimate = sorted(samples_d[n][i])[-1]  # Оценка θ = X_(n)
        s = []
        for j in range(len(samples_d[n][i])):
            lim_arg = samples_d[n][i][j] - 1
            s.append(lim_arg / estimate + uniform_samples[n][i][j] / estimate)
        work_samples[n].append(s)

# Большие выборки
for n in sizes[2:]:  # Для n >= 100
    work_samples[n] = []
    for i in range(5):
        part1 = samples_d[n][i][:len(samples_d[n][i]) // 2]  # Первая часть для оценки
        part2 = samples_d[n][i][len(samples_d[n][i]) // 2:]  # Вторая часть для проверки
        estimate = sorted(part1)[-1]  # Оценка θ = X_(n) на первой части
        s = []
        for j in range(len(part2)):
            lim_arg = part2[j] - 1
            s.append(lim_arg / estimate + uniform_samples[n][i][j] / estimate)
        work_samples[n].append(s)

# Функция для выполнения критерия Колмогорова
def kolmogorov_test(work_samples, alpha_values, Kolm_distrib):
    all_results = {}  # Словарь для хранения всех таблиц результатов

    for size in work_samples.keys():
        print(f"n = {size}\n")
        results = {f"alpha = {alpha}": [] for alpha in alpha_values}  # Результаты для каждого alpha

        for sample in work_samples[size]:  # Проход по выборкам
            sorted_sample = np.sort(sample)  # Сортировка выборки
            Dn_p = []
            Dn_m = []
            loc_size = len(sample)

            for k in range(1, loc_size + 1):
                F_empirical = k / loc_size
                F_theoretical = sci_uniform.cdf(sorted_sample[k - 1])  # Теоретическая CDF для U[0, 1]
                Dn_p.append(abs(F_empirical - F_theoretical))
                Dn_m.append(abs(F_theoretical - (k - 1) / loc_size))

            Dn = max(max(Dn_p), max(Dn_m))  # Статистика Dn

            # Вычисление Sn
            if loc_size >= 20:
                Sn = np.sqrt(loc_size) * Dn
            else:
                Sn = (6 * loc_size * Dn + 1) / (6 * np.sqrt(loc_size))

            # Проверка критерия для каждого уровня значимости
            for alpha in alpha_values:
                results[f"alpha = {alpha}"].append("H1" if Sn >= Kolm_distrib[alpha] else "H0")

        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"{i + 1}" for i in range(len(work_samples[size]))])
        all_results[size] = df

        # Вывод результатов
        print(f"n = {size}:\n")
        print(df)
        print("\n")

    return all_results


# Запуск теста
alpha_values = [0.1, 0.05, 0.01]  # Уровни значимости
results_tables = kolmogorov_test(work_samples, alpha_values, Kolm_distrib)

# Вывод значений Sn
for size, samples in work_samples.items():
    for i, sample in enumerate(samples):
        sorted_sample = np.sort(sample)
        loc_size = len(sample)
        Dn_p = []
        Dn_m = []

        for k in range(1, loc_size + 1):
            F_empirical = k / loc_size
            F_theoretical = sci_uniform.cdf(sorted_sample[k - 1])
            Dn_p.append(abs(F_empirical - F_theoretical))
            Dn_m.append(abs(F_theoretical - (k - 1) / loc_size))

        Dn = max(max(Dn_p), max(Dn_m))
        Sn = np.sqrt(loc_size) * Dn if loc_size >= 20 else (6 * loc_size * Dn + 1) / (6 * np.sqrt(loc_size))
        print(f"n = {size}, Sample {i + 1}: Sn = {np.round(Sn, 4)}")
# Out:
# n = 5
#
# n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H1           H0           H0
# 4          H1           H1           H0
# 5          H0           H0           H0
#
#
# n = 10
#
# n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H1           H1           H0
#
#
# n = 100
#
# n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 200
#
# n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# ...

# %% [markdown]
# ## хи-квадрат для сложной

# %%
# Ключевые параметры
sizes = list(samples_d.keys())  # Преобразование ключей в список для индексирования
alpha_values = [0.1, 0.05, 0.01]  # Уровни значимости
Kolm_distrib = {alpha: chi2.ppf(1 - alpha, df=77 - 1) for alpha in alpha_values}  # Квантиль хи-квадрат для df = θ - 1

# Подсчёт частот выборок
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in samples_d[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        estimate = max(samples_d[n][i])  # Оценка θ = X_(n)
        stat = 0
        for elem in freq_vector[n][i]:
            observed = freq_vector[n][i][elem]  # Наблюдаемая частота
            expected = n / estimate  # Ожидаемая частота
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)  # Добавляем значение статистики

# Функция для применения критерия согласия хи-квадрат
def chi_square_test(chi_stats, alpha_values, Kolm_distrib):
    all_results = {}  # Словарь для хранения таблиц результатов

    for n, stats in chi_stats.items():
        print(f"n = {n}\n")
        results = {f"alpha = {alpha}": [] for alpha in alpha_values}  # Результаты для каждого alpha

        for stat in stats:  # Проход по значениям статистики
            for alpha in alpha_values:
                critical_value = Kolm_distrib[alpha]  # Критическое значение
                results[f"alpha = {alpha}"].append("H1" if stat >= critical_value else "H0")

        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(len(stats))])
        all_results[n] = df

        # Вывод результатов
        print(f"Results for n = {n}:\n")
        print(df)
        print("\n")

    return all_results

# Запуск теста
results_tables = chi_square_test(chi_stats, alpha_values, Kolm_distrib)

# Вывод значений хи-квадрат
for n, stats in chi_stats.items():
    for i, stat in enumerate(stats):
        print(f"n = {n}, Sample {i + 1}: χ² = {np.round(stat, 4)}")
# Out:
# n = 5
#
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 100
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# ...

# %% [markdown]
# # Непрерывное распределение Лапласа

# %% [markdown]
# ## Выборки

# %%
sc_5_1 = [22.04173534, 21.84622421, 22.04683823, 22.05901924, 21.72051219]
sc_5_2 = [22.18443347, 22.0490527, 21.61254729, 22.0044474, 21.89559294]
sc_5_3 = [22.44057705, 21.64667251, 22.134452, 22.05129425, 22.08041521]
sc_5_4 = [21.86519076, 21.79649963, 22.02458794, 21.966596, 22.17433708]
sc_5_5 = [21.89586584, 22.03868049, 22.05096848, 21.97667662, 22.0678864]

# %%
sc_10_1 = [22.02687505, 22.04052231, 21.92460163, 21.97771776, 22.3132322 , 22.03721312, 22.24316246, 21.81945995, 21.99027478, 22.02491901]
sc_10_2 = [21.97969908, 22.27129858, 21.9295004 , 22.01341508, 21.96745477, 21.66233359, 22.01553406, 22.0400837 , 21.8688081 , 21.95268028]
sc_10_3 = [21.95289259, 22.04889578, 22.16947147, 22.05152546, 22.062262  , 22.02622824, 21.82157221, 22.03621606, 22.31573854, 21.81349971]
sc_10_4 = [22.00875354, 22.25051862, 22.02649376, 22.02009642, 22.13684922, 21.3732359 , 22.23070799, 22.01879662, 22.06783907, 22.1415092 ]
    400: [np.array(sc_400_1), np.array(sc_400_2), np.array(sc_400_3), np.array(sc_400_4), np.array(sc_400_5)],
    600: [np.array(sc_600_1), np.array(sc_600_2), np.array(sc_600_3), np.array(sc_600_4), np.array(sc_600_5)],
    800: [np.array(sc_800_1), np.array(sc_800_2), np.array(sc_800_3), np.array(sc_800_4), np.array(sc_800_5)],
    1000: [np.array(sc_1000_1), np.array(sc_1000_2), np.array(sc_1000_3), np.array(sc_1000_4), np.array(sc_1000_5)]
}

# %% [markdown]
# ## Метод моментов

# %% [markdown]
# #### Выборочное среднее и выборочная дисперсия

# %%
def sample_variance(data):
    """
    Вычисляет выборочную дисперсию вручную.
    :param data: Список или массив данных
    :return: Выборочная дисперсия
    """
    n = len(data)
    mean = sum(data) / n  # Выборочное среднее
    variance = sum((x - mean) ** 2 for x in data) / n  # Выборочная дисперсия
    return variance

# %%
# Рассчитываем выборочные средние и выборочные дисперсии для каждой выборки
results = {
    n: {
        'means': [np.mean(sample) for sample in samples],
        #'variances': [np.var(sample, ddof=0) for sample in samples]  # ddof=1 для выборочной дисперсии
        'variances': [sample_variance(sample) for sample in samples] 
    }
    for n, samples in samples_c.items()
}

# Преобразуем результаты в DataFrame для удобного просмотра
means_df = pd.DataFrame({n: results[n]['means'] for n in results})
variances_df = pd.DataFrame({n: results[n]['variances'] for n in results})

# %%
means_df
# Out:
#         5          10         100        200        400        600   \
# 0  21.942866  22.039798  21.974956  21.998446  22.008341  22.014678
# 1  21.949215  21.970081  22.019188  21.996518  21.986071  22.004593
# 2  22.070682  22.029830  21.986599  22.006156  21.998084  21.983399
# 3  21.965442  22.027480  21.998890  21.983307  21.989330  21.994507
# 4  22.006016  22.069981  22.012103  21.992554  22.005260  22.000285
#
#         800        1000
# 0  22.000643  22.003883
# 1  22.016358  21.998941
# 2  22.000688  22.008690
# 3  22.005761  22.003376
# 4  22.000504  22.002820

# %%
variances_df
# Out:
#        5         10        100       200       400       600       800   \
# 0  0.018572  0.018464  0.029037  0.033468  0.033051  0.034491  0.037615
# 1  0.036913  0.020659  0.030783  0.032683  0.028290  0.035099  0.037444
# 2  0.064229  0.019927  0.040178  0.029401  0.043839  0.032117  0.030298
# 3  0.017146  0.054616  0.040738  0.038731  0.039077  0.031668  0.034102
# 4  0.003982  0.114295  0.040316  0.028830  0.025946  0.031421  0.037054
#
#        1000
# 0  0.034740
# 1  0.035952
# 2  0.038867
# 3  0.037066
# 4  0.034464

# %% [markdown]
# #### Оценка параметра

# %%
# Функция для оценки параметров методом моментов для распределения Лапласа
def laplace_moments_estimation(sample):
    """
    Оценка параметров распределения Лапласа методом моментов.
    :param sample: Список или массив выборки
    :return: Оценки параметров (mu, theta)
    """
    n = len(sample)
    mean = sum(sample) / n  # Выборочное среднее
    variance = sum((x - mean)**2 for x in sample) / n  # Выборочная дисперсия (деление на n)
    theta = (2 / variance)**0.5  # Оценка theta
    return mean, theta

# %%
# Рассчитываем оценки параметров для каждой выборки
moment_estimates = {
    n: [laplace_moments_estimation(sample) for sample in samples]
    for n, samples in samples_c.items()
}

# Преобразуем результаты в DataFrame для удобного просмотра
moment_means_df = pd.DataFrame({n: [est[0] for est in moment_estimates[n]] for n in moment_estimates})
moment_thetas_df = pd.DataFrame({n: [est[1] for est in moment_estimates[n]] for n in moment_estimates})

# %%
moment_means_df
# Out:
#         5          10         100        200        400        600   \
# 0  21.942866  22.039798  21.974956  21.998446  22.008341  22.014678
# 1  21.949215  21.970081  22.019188  21.996518  21.986071  22.004593
# 2  22.070682  22.029830  21.986599  22.006156  21.998084  21.983399
# 3  21.965442  22.027480  21.998890  21.983307  21.989330  21.994507
# 4  22.006016  22.069981  22.012103  21.992554  22.005260  22.000285
#
#         800        1000
# 0  22.000643  22.003883
# 1  22.016358  21.998941
# 2  22.000688  22.008690
# 3  22.005761  22.003376
# 4  22.000504  22.002820

# %%
moment_thetas_df
# Out:
#         5          10        100       200       400       600       800   \
# 0  10.377454  10.407509  8.299201  7.730391  7.779032  7.614816  7.291790
# 1   7.360778   9.839216  8.060510  7.822655  8.408152  7.548568  7.308455
# 2   5.580207  10.018233  7.055390  8.247729  6.754404  7.891242  8.124647
# 3  10.800335   6.051400  7.006714  7.185941  7.154069  7.946989  7.658224
# 4  22.411444   4.183131  7.043269  8.328962  8.779717  7.978154  7.346758
#
#        1000
# 0  7.587478
# 1  7.458549
# 2  7.173391
# 3  7.345550
# 4  7.617792

# %% [markdown]
# ## Метод максимального правдоподобия

# %%
def laplace_mle(sample):
    """
    Оценка параметров распределения Лапласа методом максимального правдоподобия.
    :param sample: Список или массив выборки
    :return: Оценки параметров (mu, theta)
    """
    # Оценка mu (медиана выборки)
    mu = np.median(sample)
    #print(mu in sample)
    # Оценка theta
    theta = len(sample) / np.sum(np.abs(sample - mu))
    
    return mu, theta

# %%
# Рассчитываем оценки параметров для каждой выборки
mle_estimates = {
    n: [laplace_mle(sample) for sample in samples]
    for n, samples in samples_c.items()
}

# Преобразуем результаты в DataFrame для удобного просмотра
mle_means_df = pd.DataFrame({n: [est[0] for est in mle_estimates[n]] for n in mle_estimates})
mle_thetas_df = pd.DataFrame({n: [est[1] for est in mle_estimates[n]] for n in mle_estimates})

# %%
mle_means_df
# Out:
#         5          10         100        200        400        600   \
# 0  22.041735  22.025897  21.985863  22.000061  22.006376  22.012371
# 1  22.004447  21.973577  22.012184  21.997400  21.994274  22.001975
# 2  22.080415  22.042556  21.981292  22.001518  21.988611  21.998470
# 3  21.966596  22.047166  22.001126  22.002547  21.988571  21.997592
# 4  22.038680  21.975081  22.005543  21.986625  22.008490  22.002197
#
#         800        1000
# 0  22.006919  22.003322
# 1  22.004624  22.001386
# 2  22.004009  22.006326
# 3  22.004145  21.998165
# 4  21.996982  21.997025

# %%
mle_thetas_df
# Out:
#         5          10        100       200       400       600       800   \
# 0   9.274355  10.822136  8.144349  7.630685  7.569478  7.655102  7.415124
# 1   6.893263  10.646755  8.020382  7.931339  8.280024  7.504690  7.138736
# 2   5.700849  10.025219  7.241377  8.279414  6.848954  7.676734  8.070918
# 3   9.306921   7.246126  7.233615  7.173178  7.182060  7.755750  7.649918
# 4  20.299423   3.959926  7.113093  7.900682  8.317780  7.882622  7.489018
#
#        1000
# 0  7.384994
# 1  7.422682
# 2  7.209241
# 3  7.415366
# 4  7.567802

# %% [markdown]
# ## Оптимальная оценка

# %%
def laplace_tau_estimation(sample):
    """
    Оценка параметра τ(θ) = 1/θ для распределения Лапласа.
    :param sample: Список или массив выборки
    :return: Оценка τ(θ)
    """
    # Оценка mu (медиана выборки)
    mu = np.median(sample)
    # Оценка τ(θ) = H = sum(|x_i - mu|) / n
    tau = np.mean(np.abs(sample - mu))
    return tau

# %%
# Рассчитываем оценки τ(θ) для каждой выборки
tau_estimates = {
    n: [laplace_tau_estimation(sample) for sample in samples]
    for n, samples in samples_c.items()
}

# Преобразуем результаты в DataFrame для удобного просмотра
tau_df = pd.DataFrame(tau_estimates)

# %%
tau_df
# Out:
#        5         10        100       200       400       600       800   \
# 0  0.107824  0.092403  0.122785  0.131050  0.132110  0.130632  0.134860
# 1  0.145069  0.093925  0.124682  0.126082  0.120773  0.133250  0.140081
# 2  0.175412  0.099748  0.138095  0.120782  0.146008  0.130264  0.123902
# 3  0.107447  0.138005  0.138243  0.139408  0.139236  0.128937  0.130720
# 4  0.049262  0.252530  0.140586  0.126571  0.120224  0.126861  0.133529
#
#        1000
# 0  0.135410
# 1  0.134722
# 2  0.138711
# 3  0.134855
# 4  0.132139

# %% [markdown]
# ## Задача

# %%
df = pd.read_csv("Bias_correction_ucl.csv", sep=",") #считали данные
df.head() #чтобы видеть, с чем имеем дело
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0  2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0  2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0  2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0  2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %% [markdown]
# #### Обработка датасета

# %%
columns_to_drop = ["LDAPS_PPT2", "LDAPS_PPT3", "LDAPS_PPT4", "lat","lon","DEM","Slope","Solar radiation","LDAPS_RHmin","LDAPS_RHmax","LDAPS_WS","LDAPS_LH","LDAPS_PPT1","LDAPS_CC1","LDAPS_CC2","LDAPS_CC3","LDAPS_CC4","","","","","","",""]  # Замените на реальные названия столбцов

# Удаление указанных столбцов из DataFrame
df = df.drop(columns=columns_to_drop, errors="ignore")
df[5:100]
# Out:
#     station        Date  Present_Tmax  Present_Tmin  LDAPS_Tmax_lapse  \
# 5       6.0  2013-06-30          31.9          23.5         29.219342
# 6       7.0  2013-06-30          31.4          24.4         28.551859
# 7       8.0  2013-06-30          32.1          23.6         28.851982
# 8       9.0  2013-06-30          31.4          22.0         28.426975
# 9      10.0  2013-06-30          31.6          20.5         27.576705
# ..      ...         ...           ...           ...               ...
# 95     21.0  2013-07-03          30.3          20.7         30.741564
# 96     22.0  2013-07-03          31.3          21.1         30.141404
# 97     23.0  2013-07-03          31.0          20.5         28.955439
# 98     24.0  2013-07-03          30.1          20.7         29.490573
# 99     25.0  2013-07-03          30.8          20.8         30.363160
#
#     LDAPS_Tmin_lapse  Next_Tmax  Next_Tmin
# 5          23.822613       31.5       24.0
# ...

# %%
# Оставляем только строки, где значение в столбце 'station' равно 1
df_station_1 = df[df['station'] == 1.0]

# Отображаем результат
df_station_1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_Tmax_lapse  \
# 0         1.0  2013-06-30          28.7          21.4         28.074101
# 25        1.0  2013-07-01          28.3          21.2         25.276716
# 50        1.0  2013-07-02          24.4          20.6         27.785497
# 75        1.0  2013-07-03          27.9          17.9         28.125651
# 100       1.0  2013-07-04          24.9          21.5         30.458252
# ...       ...         ...           ...           ...               ...
# 7625      1.0  2017-08-26          25.2          18.1         23.725956
# 7650      1.0  2017-08-27          23.2          17.7         24.186341
# 7675      1.0  2017-08-28          23.2          16.0         21.253708
# 7700      1.0  2017-08-29          20.3          15.7         20.283129
# 7725      1.0  2017-08-30          20.0          15.1         24.323737
#
#       LDAPS_Tmin_lapse  Next_Tmax  Next_Tmin
# 0            23.006936       29.1       21.2
# ...

# %%
# Сдвигаем столбцы "Next_Tmax" и "Next_Tmin" вниз на одну строку
#df_station_1['Next_Tmax'] = df_station_1['Next_Tmax'].shift(1)
#df_station_1['Next_Tmin'] = df_station_1['Next_Tmin'].shift(1)

# Удаляем первую строку
df_station_1 = df_station_1.iloc[1:]

# Отображаем результат
df_station_1.head()
# Out:
#      station        Date  Present_Tmax  Present_Tmin  LDAPS_Tmax_lapse  \
# 25       1.0  2013-07-01          28.3          21.2         25.276716
# 50       1.0  2013-07-02          24.4          20.6         27.785497
# 75       1.0  2013-07-03          27.9          17.9         28.125651
# 100      1.0  2013-07-04          24.9          21.5         30.458252
# 125      1.0  2013-07-05          27.8          19.9         29.855779
#
#      LDAPS_Tmin_lapse  Next_Tmax  Next_Tmin
# 25          21.142562       24.8       18.7
# 50          19.561770       28.1       17.8
# 75          21.982579       25.2       20.8
# 100         22.077078       28.0       19.7
# 125         21.121298       28.2       19.3

# %%
columns_to_drop = ["LDAPS_Tmax_lapse", "LDAPS_Tmin_lapse"]

# Удаление указанных столбцов из DataFrame
df_station_1 = df_station_1.drop(columns=columns_to_drop, errors="ignore")
df_station_1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  Next_Tmax  Next_Tmin
# 25        1.0  2013-07-01          28.3          21.2       24.8       18.7
# 50        1.0  2013-07-02          24.4          20.6       28.1       17.8
# 75        1.0  2013-07-03          27.9          17.9       25.2       20.8
# 100       1.0  2013-07-04          24.9          21.5       28.0       19.7
# 125       1.0  2013-07-05          27.8          19.9       28.2       19.3
# ...       ...         ...           ...           ...        ...        ...
# 7625      1.0  2017-08-26          25.2          18.1       23.5       17.2
# 7650      1.0  2017-08-27          23.2          17.7       24.2       15.9
# 7675      1.0  2017-08-28          23.2          16.0       20.8       13.6
# 7700      1.0  2017-08-29          20.3          15.7       20.4       14.6
# 7725      1.0  2017-08-30          20.0          15.1       23.8       15.1
#
# [309 rows x 6 columns]

# %%
# Создаем новые столбцы pred_tmax и pred_tmin, которые содержат значения столбцов Next_Tmax и Next_Tmin предыдущей строки
df_station_1['pred_tmax'] = df_station_1['Next_Tmax'].shift(1)
df_station_1['pred_tmin'] = df_station_1['Next_Tmin'].shift(1)
df_station_1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  Next_Tmax  Next_Tmin  \
# 25        1.0  2013-07-01          28.3          21.2       24.8       18.7
# 50        1.0  2013-07-02          24.4          20.6       28.1       17.8
# 75        1.0  2013-07-03          27.9          17.9       25.2       20.8
# 100       1.0  2013-07-04          24.9          21.5       28.0       19.7
# 125       1.0  2013-07-05          27.8          19.9       28.2       19.3
# ...       ...         ...           ...           ...        ...        ...
# 7625      1.0  2017-08-26          25.2          18.1       23.5       17.2
# 7650      1.0  2017-08-27          23.2          17.7       24.2       15.9
# 7675      1.0  2017-08-28          23.2          16.0       20.8       13.6
# 7700      1.0  2017-08-29          20.3          15.7       20.4       14.6
# 7725      1.0  2017-08-30          20.0          15.1       23.8       15.1
#
#       pred_tmax  pred_tmin
# 25          NaN        NaN
# ...

# %%
columns_to_drop = ["Next_Tmax", "Next_Tmin"]

# Удаление указанных столбцов из DataFrame
df_station_1 = df_station_1.drop(columns=columns_to_drop, errors="ignore")
df_station_1 = df_station_1.iloc[1:]
df_station_1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  pred_tmax  pred_tmin
# 50        1.0  2013-07-02          24.4          20.6       24.8       18.7
# 75        1.0  2013-07-03          27.9          17.9       28.1       17.8
# 100       1.0  2013-07-04          24.9          21.5       25.2       20.8
# 125       1.0  2013-07-05          27.8          19.9       28.0       19.7
# 150       1.0  2013-07-06          27.6          19.6       28.2       19.3
# ...       ...         ...           ...           ...        ...        ...
# 7625      1.0  2017-08-26          25.2          18.1       25.8       17.8
# 7650      1.0  2017-08-27          23.2          17.7       23.5       17.2
# 7675      1.0  2017-08-28          23.2          16.0       24.2       15.9
# 7700      1.0  2017-08-29          20.3          15.7       20.8       13.6
# 7725      1.0  2017-08-30          20.0          15.1       20.4       14.6
#
# [308 rows x 6 columns]

# %%
# Чтобы избежать предупреждений, используем безопасный подход без inplace
df_station_1['Present_Tmax'] = df_station_1['Present_Tmax'].fillna(df_station_1['pred_tmax'])
df_station_1['Present_Tmin'] = df_station_1['Present_Tmin'].fillna(df_station_1['pred_tmin'])

df_station_1[1:10]


# Добавляем новые столбцы для расчета потерь
df_station_1['loss_max'] = df_station_1['pred_tmax'] - df_station_1['Present_Tmax']
df_station_1['loss_min'] = df_station_1['pred_tmin'] - df_station_1['Present_Tmin']

# Расчет средней потери
present_mean = (df_station_1['Present_Tmax'] + df_station_1['Present_Tmin']) / 2
pred_mean = (df_station_1['pred_tmax'] + df_station_1['pred_tmin']) / 2
df_station_1['loss_mean'] = pred_mean - present_mean

df_station_1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  pred_tmax  pred_tmin  \
# 50        1.0  2013-07-02          24.4          20.6       24.8       18.7
# 75        1.0  2013-07-03          27.9          17.9       28.1       17.8
# 100       1.0  2013-07-04          24.9          21.5       25.2       20.8
# 125       1.0  2013-07-05          27.8          19.9       28.0       19.7
# 150       1.0  2013-07-06          27.6          19.6       28.2       19.3
# ...       ...         ...           ...           ...        ...        ...
# 7625      1.0  2017-08-26          25.2          18.1       25.8       17.8
# 7650      1.0  2017-08-27          23.2          17.7       23.5       17.2
# 7675      1.0  2017-08-28          23.2          16.0       24.2       15.9
# 7700      1.0  2017-08-29          20.3          15.7       20.8       13.6
# 7725      1.0  2017-08-30          20.0          15.1       20.4       14.6
#
#       loss_max  loss_min  loss_mean
# ...

# %%
print(sum(df_station_1['loss_max']))
print(sum(df_station_1['loss_min']))
print(sum(df_station_1['loss_mean']))
# Out:
# 177.3999999999999
# -82.00000000000001
# 47.7

# %% [markdown]
# #### Работа с полученной выборкой

# %%
#предсказания средней температуры

# %%
# Преобразуем столбец 'loss_min' в numpy массив
loss_mean_array = df_station_1['loss_mean'].to_numpy()

# Проверяем результат
loss_mean_array[:10]  # Выводим первые 10 элементов массива для проверки
# Out:
# array([-7.50000000e-01,  5.00000000e-02, -2.00000000e-01,  0.00000000e+00,
#         1.50000000e-01,  5.00000000e-01, -3.55271368e-15,  0.00000000e+00,
#         5.00000000e-02,  0.00000000e+00])

# %%
loss_mean_array_mean = np.round(np.mean(loss_mean_array), 2)
loss_mean_array_mean
# Out:
# 0.15

# %%
loss_mean_array_variance =np.round(np.mean((np.array(loss_mean_array) - loss_mean_array_mean)**2), 2)
loss_mean_array_variance
# Out:
# 0.29

# %%
mm_mu = loss_mean_array_mean
mm_theta = np.sqrt(2/loss_mean_array_variance)
print(mm_mu)
print(mm_theta)
# Out:
# 0.15
# 2.6261286571944513

# %%
mmp_mu = np.median(loss_mean_array)
mmp_theta = len(loss_mean_array) / np.sum(np.abs(loss_mean_array - mmp_mu))
print(mmp_mu)
print(mmp_theta)
# Out:
# 0.15000000000000213
# 4.418938307030125

# %%
#оптимальная для 1/theta
theta_opt_1 = np.sum(np.abs(loss_mean_array - mmp_mu)) / len(loss_mean_array)
print(theta_opt_1)
#оптимальная для theta
print(1/theta_opt_1)
# Out:
# 0.22629870129870153
# 4.418938307030125

# %%
# Функция для вычисления функции распределения Лапласа
def laplace_cdf(x, mu, theta):
    return np.where(x < mu, 0.5 * np.exp(theta * (x - mu)), 1 - 0.5 * np.exp(-theta * (x - mu)))

# %%
# Параметры распределения Лапласа
mu = 0.15000000000000213
#theta = 4.418938307030125
theta = 4.8

# Диапазон значений для t
t_values_continuous = np.linspace(-10, 10, 100000)

# Вычисляем функцию распределения для распределения Лапласа
laplace_cdf_values = laplace_cdf(t_values_continuous, mu, theta)

# Создаем график
plt.figure(figsize=(8, 6))

# Эмпирическая ФР
empirical_cdf_values = [np.sum(loss_mean_array <= t) / len(loss_mean_array) for t in t_values_continuous]
plt.plot(t_values_continuous, empirical_cdf_values, label="ЭФР выборки", alpha=0.8, color="red")

# Теоретическая ФР
plt.plot(t_values_continuous, laplace_cdf_values, label='Теоретическая ФР', linestyle="--", color="black")

# Вертикальная линия для mu
plt.axvline(x=mu, color='pink', alpha=0.6, label=f"μ = {mu:.3f}")

# Оформление графика
#plt.title('ФР и ЭФР для выборки ошибок прогноза')
plt.grid(True)
plt.legend()

plt.xlim(-2, 2.15)
# Отображение графика
plt.show()
#plt.savefig(f'hw3_realData_nepr.png', dpi=300)

# %% [markdown]
# ## Критерий согласия Колмогорова

# %%
# Теоретическая функция распределения Лапласа
def laplace_cdf(x, mu, theta):
    if x <= mu:
        return 0.5 * np.exp(theta * (x - mu))
    else:
        return 1 - 0.5 * np.exp(-theta * (x - mu))

# %%
# Расчет статистики D_n вручную
def kolmogorov_statistic_manual(sample, mu, theta):
    n = len(sample)
    sorted_sample = np.sort(sample)
    ecdf = np.arange(1, n + 1) / n  # Эмпирическая ФР

    # Теоретическая ФР
    cdf = np.array([laplace_cdf(x, mu, theta) for x in sorted_sample])

    # D_n как максимум разности между ЭФР и теоретической ФР
    d_plus = np.max(ecdf - cdf)
    d_minus = np.max(cdf - (ecdf - 1 / n))
    d_n = max(d_plus, d_minus)
    return d_n

# Тест Колмогорова для каждой выборки
def kolmogorov_test_manual(samples, alpha_values, mu, theta):
    results = {}
    for n, sample_group in samples.items():
        group_results = []
        for sample in sample_group:
            # Статистика D_n
            d_n = kolmogorov_statistic_manual(sample, mu, theta)
            
            # Выбор статистики для n < 20 и n >= 20
            if n >= 20:
                statistic = np.sqrt(n) * d_n
            else:
                statistic = (6 * n * d_n + 1) / (6 * np.sqrt(n))
            
            # Проверка гипотез для каждого уровня значимости
            row_result = []
            for alpha in alpha_values:
                if statistic >= critical_values[alpha]:
                    #row_result.append("H1")  # Основная гипотеза отклонена
                    row_result.append(statistic)
                else:
                    #row_result.append("H0")  # Основная гипотеза не отклонена
                    row_result.append(statistic)
            group_results.append(row_result)
        results[n] = group_results
    return results

# %%
# Параметры распределения Лапласа
mu = 22
theta = 7.5

# Уровни значимости
alpha_values = [0.1, 0.05, 0.01]

# Критические значения для теста Колмогорова
critical_values = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}

# %%
# Применение теста
test_results_manual = kolmogorov_test_manual(samples_c, alpha_values, mu, theta)

# Вывод результатов
for n, results in test_results_manual.items():
    print(f"Результаты теста для n = {n}:")
    df = pd.DataFrame(results, columns=[f"{alpha}" for alpha in alpha_values], index=[f"выборка {i+1}" for i in range(len(results))])
    print(df)
    print("\n")
# Out:
# Результаты теста для n = 5:
#                 0.1      0.05      0.01
# выборка 1  2.310604  2.310604  2.310604
# выборка 2  2.310604  2.310604  2.310604
# выборка 3  2.310604  2.310604  2.310604
# выборка 4  2.310604  2.310604  2.310604
# выборка 5  2.310604  2.310604  2.310604
#
#
# Результаты теста для n = 10:
#                 0.1      0.05      0.01
# выборка 1  3.214982  3.214982  3.214982
# выборка 2  3.214982  3.214982  3.214982
# выборка 3  3.214982  3.214982  3.214982
# выборка 4  3.214982  3.214982  3.214982
# выборка 5  3.214982  3.214982  3.214982
#
#
# Результаты теста для n = 100:
#             0.1  0.05  0.01
# выборка 1  10.0  10.0  10.0
# выборка 2  10.0  10.0  10.0
# выборка 3  10.0  10.0  10.0
# выборка 4  10.0  10.0  10.0
# выборка 5  10.0  10.0  10.0
#
#
# Результаты теста для n = 200:
#                  0.1       0.05       0.01
# выборка 1  14.142136  14.142136  14.142136
# выборка 2  14.142136  14.142136  14.142136
# ...

# %%
# Истинные параметры распределения Лапласа
mu = 22
theta = 7.5

# Критические значения
Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}

# %%
# Теоретическая функция распределения Лапласа
def laplace_cdf(x, mu, theta):
    if x <= mu:
        return 0.5 * np.exp(theta * (x - mu))
    else:
        return 1 - 0.5 * np.exp(-theta * (x - mu))

# %%
# Реализация критерия Колмогорова-Ходжеса
for size, sample_group in samples_c.items():
    print(f"n = {size}\n")
    results = {0.1: [], 0.05: [], 0.01: []}
    for i, sample in enumerate(sample_group):
        sorted_sample = sorted(sample)
        Dn_p = []
        Dn_m = []
        for k in (np.arange(size) + 1):
            # Теоретическая ФР и расчет D_plus и D_minus
            F_x = laplace_cdf(sorted_sample[k-1], mu, theta)
            Dn_p.append(np.abs(k / size - F_x))
            Dn_m.append(np.abs(F_x - (k - 1) / size))
        Dn = max(max(Dn_p), max(Dn_m))

        # Вычисление статистики S_n
        if size >= 20:
            Sn = np.sqrt(size) * Dn
        else:
            Sn = (6 * size * Dn + 1) / (6 * np.sqrt(size))

        # Проверка гипотез
        for alpha in Kolm_distrib.keys():
            results[alpha].append(int(Sn >= Kolm_distrib[alpha]))

    # Визуализация результатов
    fig, ax = plt.subplots(6, 4, figsize=(7, 3), sharex=True, sharey=True)

    ax[0][0].add_patch(plt.Rectangle((0, 0), 1, 1, color='grey', alpha=0.3))
    ax[0][0].text(0.45, 0.3, 'i', size=15)
    for i in (np.arange(5) + 1):
        ax[i][0].add_patch(plt.Rectangle((0, 0), 1, 1, color='grey', alpha=0.3))
        ax[i][0].text(0.4, 0.3, i, size=15)

    ax[0][1].add_patch(plt.Rectangle((0, 0), 1, 1, color='grey', alpha=0.3))
    ax[0][1].text(0.1, 0.3, 'alpha=0.1', size=15)
    for i in (np.arange(5) + 1):
        ax[i][1].add_patch(plt.Rectangle((0, 0), 1, 1, color='white', alpha=0.3))
        ax[i][1].text(0.4, 0.3, ("H0" if results[0.1][i-1] == 0 else "H1"), size=15)

    ax[0][2].add_patch(plt.Rectangle((0, 0), 1, 1, color='grey', alpha=0.3))
    ax[0][2].text(0.05, 0.3, 'alpha=0.05', size=15)
    for i in (np.arange(5) + 1):
        ax[i][2].add_patch(plt.Rectangle((0, 0), 1, 1, color='white', alpha=0.3))
        ax[i][2].text(0.4, 0.3, ("H0" if results[0.05][i-1] == 0 else "H1"), size=15)

    ax[0][3].add_patch(plt.Rectangle((0, 0), 1, 1, color='grey', alpha=0.3))
    ax[0][3].text(0.05, 0.3, 'alpha=0.01', size=15)
    for i in (np.arange(5) + 1):
        ax[i][3].add_patch(plt.Rectangle((0, 0), 1, 1, color='white', alpha=0.3))
        ax[i][3].text(0.4, 0.3, ("H0" if results[0.01][i-1] == 0 else "H1"), size=15)

    ax[0][0].set_xticks([])
    ax[0][0].set_yticks([])
    fig.subplots_adjust(hspace=0, wspace=0)
    plt.show()
    print('----------------------')
# Out:
# n = 5
# ----------------------
# n = 10
# ----------------------
# n = 100
# ----------------------
# n = 200
# ----------------------
# n = 400
# ----------------------
# n = 600
# ----------------------
# n = 800
# ----------------------
# n = 1000
# ----------------------

# %%
# Функция для выполнения теста Колмогорова-Ходжеса и вывода результатов в виде таблиц
def kolmogorov_test_table_with_alpha(samples, mu, theta, alpha_values, critical_values):
    all_results = {}
    for size, sample_group in samples.items():
        results = {f"alpha = {alpha}": [] for alpha in alpha_values}
        for sample in sample_group:
            sorted_sample = sorted(sample)
            Dn_p = []
            Dn_m = []
            for k in (np.arange(size) + 1):
                F_x = laplace_cdf(sorted_sample[k-1], mu, theta)
                Dn_p.append(np.abs(k / size - F_x))
                Dn_m.append(np.abs(F_x - (k - 1) / size))
            Dn = max(max(Dn_p), max(Dn_m))

            if size >= 20:
                Sn = np.sqrt(size) * Dn
            else:
                Sn = (6 * size * Dn + 1) / (6 * np.sqrt(size))

            for alpha in alpha_values:
                results[f"alpha = {alpha}"].append("H1" if Sn >= critical_values[alpha] else "H0")
        
        df = pd.DataFrame(results, index=[f"{i+1}" for i in range(len(sample_group))])
        all_results[size] = df
        print(f"n = {size}:\n")
        print(df)
        print("\n")
    return all_results

# Уровни значимости
alpha_values = [0.1, 0.05, 0.01]

# Выполнение теста
results_tables_with_alpha = kolmogorov_test_table_with_alpha(samples_c, mu, theta, alpha_values, Kolm_distrib)
# Out:
# n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H1           H1           H0
# 5          H0           H0           H0
#
#
# n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# ...

# %% [markdown]
# ## хи - квадрат

# %%
def laplace_quantile(p, mu, theta):
    """
    Вычисление квантили для распределения Лапласа.
    
    :param p: Уровень вероятности (0 < p < 1).
    :param mu: Параметр распределения (медиана).
    :param theta: Масштабный параметр распределения.
    :return: Квантиль соответствующий уровню вероятности p.
    """
    if p < 0.5:
        # Левая часть (x < mu)
        return mu + np.log(2 * p) / theta
    else:
        # Правая часть (x >= mu)
        return mu - np.log(2 * (1 - p)) / theta

# Пример: параметры
mu = 22
theta = 7.5

# %%
# Уровни вероятности (квантили)
p_values = [1/3, 2/3]

# Вычисление квантилей для разных уровней вероятности
quantiles = [laplace_quantile(p, mu, theta) for p in p_values]

# Вывод результатов
for p, q in zip(p_values, quantiles):
    print(f"Квантиль для p = {p}: {q}")
# Out:
# Квантиль для p = 0.3333333333333333: 21.945937985585577
# Квантиль для p = 0.6666666666666666: 22.054062014414423

# %%
# Уровни вероятности (квантили)
p_values = [1/5, 2/5, 3/5, 4/5]

# Вычисление квантилей для разных уровней вероятности
quantiles = [laplace_quantile(p, mu, theta) for p in p_values]

# Вывод результатов
for p, q in zip(p_values, quantiles):
    print(f"Квантиль для p = {p}: {q}")
# Out:
# Квантиль для p = 0.2: 21.87782790241678
# Квантиль для p = 0.4: 21.970247526491438
# Квантиль для p = 0.6: 22.029752473508562
# Квантиль для p = 0.8: 22.12217209758322

# %%
# Уровни вероятности (квантили)
p_values = [1/10, 2/10, 3/10, 4/10, 5/10, 6/10, 7/10, 8/10, 9/10]

# Вычисление квантилей для разных уровней вероятности
quantiles = [laplace_quantile(p, mu, theta) for p in p_values]

# Вывод результатов
for p, q in zip(p_values, quantiles):
    print(f"Квантиль для p = {p}: {q}")
# Out:
# Квантиль для p = 0.1: 21.78540827834212
# Квантиль для p = 0.2: 21.87782790241678
# Квантиль для p = 0.3: 21.931889916831203
# Квантиль для p = 0.4: 21.970247526491438
# Квантиль для p = 0.5: 22.0
# Квантиль для p = 0.6: 22.029752473508562
# Квантиль для p = 0.7: 22.068110083168797
# Квантиль для p = 0.8: 22.12217209758322
# Квантиль для p = 0.9: 22.21459172165788

# %%
def compute_chi_square_statistics(alpha_levels, degrees_of_freedom):
    """
    Вычисление критических значений хи-квадрат для заданных уровней значимости и степеней свободы.
    
    :param alpha_levels: Список уровней значимости (например, [0.1, 0.05, 0.01]).
    :param degrees_of_freedom: Список степеней свободы (например, [1, 2, 3, ..., 10]).
    :return: Словарь критических значений хи-квадрат для каждой комбинации.
    """
    chi_square_values = {}
    
    for df in degrees_of_freedom:
        chi_square_values[df] = {}
        for alpha in alpha_levels:
            critical_value = chi2.ppf(1 - alpha, df)
            chi_square_values[df][f"alpha={alpha}"] = critical_value
    
    return chi_square_values

# Пример входных данных
alpha_levels = [0.1, 0.05, 0.01]  # Уровни значимости
degrees_of_freedom = [3-1,5-1,10-1]  # Степени свободы от 1 до 10

# Вычисляем критические значения
chi_square_results = compute_chi_square_statistics(alpha_levels, degrees_of_freedom)

# Выводим результаты в удобной таблице
import pandas as pd

chi_square_df = pd.DataFrame(chi_square_results).T  # Создаем DataFrame для вывода
print(chi_square_df)
# Out:
#    alpha=0.1  alpha=0.05  alpha=0.01
# 2   4.605170    5.991465    9.210340
# 4   7.779440    9.487729   13.276704
# 9  14.683657   16.918978   21.665994

# %%
# Параметры разбиения
N = 3  # Количество интервалов
bounds = [-np.inf, 21.95, 22.05, np.inf]  # Границы интервалов
sizes = samples_c.keys()  # Размеры выборок

# Квантили хи-квадрат
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 1),
    0.05: chi2.ppf(1 - 0.05, df=N - 1),
    0.01: chi2.ppf(1 - 0.01, df=N - 1),
}

# Группировка выборок по интервалам
grouped_samples = {}
for n in sizes:
    grouped_samples[n] = []
    for sample in samples_c[n]:
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n / N
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Результаты теста
def chi_square_test(chi_stats, critical_values):
    results_all = {}
    for n, stats in chi_stats.items():
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")

        # Вывод таблицы результатов
        print(f"Results for n = {n}:\n")
        df = pd.DataFrame(results, index=[f"{i + 1}" for i in range(len(stats))])
        print(df)
        print("\n")
        results_all[n] = df
    return results_all

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений X^2
for n in sizes:
    for i, stat in enumerate(chi_stats[n]):
        print(f"n={n}, Sample {i + 1}: X^2 = {np.round(stat, 2)}")
# Out:
# Results for n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H1           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# ...

# %%
# Параметры разбиения для N=5
N = 5
bounds = [-np.inf, 21.88, 21.97, 22.03, 22.12, np.inf]  # Границы интервалов
sizes = samples_c.keys()  # Размеры выборок

# Квантили хи-квадрат для N=5
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 1),
    0.05: chi2.ppf(1 - 0.05, df=N - 1),
    0.01: chi2.ppf(1 - 0.01, df=N - 1),
}

# Группировка выборок по интервалам
grouped_samples = {}
for n in sizes:
    grouped_samples[n] = []
    for sample in samples_c[n]:
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n / N
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Результаты теста
def chi_square_test(chi_stats, critical_values):
    results_all = {}
    for n, stats in chi_stats.items():
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")

        # Вывод таблицы результатов
        print(f"Results for n = {n}:\n")
        df = pd.DataFrame(results, index=[f"{i + 1}" for i in range(len(stats))])
        print(df)
        print("\n")
        results_all[n] = df
    return results_all

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений X^2
for n in sizes:
    for i, stat in enumerate(chi_stats[n]):
        print(f"n={n}, Sample {i + 1}: X^2 = {np.round(stat, 2)}")
# Out:
# Results for n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H1           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# ...

# %%
# Параметры разбиения для N=10
N = 10
bounds = [-np.inf, 21.79, 21.88, 21.93, 21.97, 22.0, 22.03, 22.07, 22.12, 22.21, np.inf]  # Границы интервалов
sizes = samples_c.keys()  # Размеры выборок

# Квантили хи-квадрат для N=10
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 1),
    0.05: chi2.ppf(1 - 0.05, df=N - 1),
    0.01: chi2.ppf(1 - 0.01, df=N - 1),
}

# Группировка выборок по интервалам
grouped_samples = {}
for n in sizes:
    grouped_samples[n] = []
    for sample in samples_c[n]:
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n / N
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Результаты теста
def chi_square_test(chi_stats, critical_values):
    results_all = {}
    for n, stats in chi_stats.items():
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")

        # Вывод таблицы результатов
        print(f"Results for n = {n}:\n")
        df = pd.DataFrame(results, index=[f"{i + 1}" for i in range(len(stats))])
        print(df)
        print("\n")
        results_all[n] = df
    return results_all

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений X^2
for n in sizes:
    for i, stat in enumerate(chi_stats[n]):
        print(f"n={n}, Sample {i + 1}: X^2 = {np.round(stat, 2)}")
# Out:
# Results for n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H1           H1           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H1           H1           H0
#
#
# Results for n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H1           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# Results for n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# ...

# %% [markdown]
# ## Колмогоров для сложной гипотезы

# %% [markdown]
# для малых n < 20

# %%
sizes = samples_c.keys()
mu = 22  # Заданное значение

# Функция для оценки параметра θ
def laplace_theta(sample, mu):
    return len(sample) / np.sum(np.abs(sample - mu))

# Функция теоретической ФР для распределения Лапласа
def laplace_cdf(x, mu, theta):
    if x < mu:
        return 0.5 * np.exp(theta * (x - mu))
    else:
        return 1 - 0.5 * np.exp(-theta * (x - mu))

# Критические значения для малых выборок
Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}

# Рассчитываем θ и проверяем критерий Колмогорова
results_tables = {}
for size in sizes:
    results = {f"alpha = {alpha}": [] for alpha in Kolm_distrib.keys()}
    chi_stats = []
    
    for sample in samples_c[size]:
        # Оцениваем θ
        theta = laplace_theta(sample, mu)
        
        # Сортируем выборку
        sorted_sample = np.sort(sample)
        
        # Вычисляем статистику Колмогорова
        Dn_p = []
        Dn_m = []
        for k in range(1, size + 1):
            F_empirical = k / size
            F_theoretical = laplace_cdf(sorted_sample[k - 1], mu, theta)
            Dn_p.append(np.abs(F_empirical - F_theoretical))
            Dn_m.append(np.abs(F_theoretical - (k - 1) / size))
        Dn = max(max(Dn_p), max(Dn_m))
        
        # Приводим статистику к форме Sn для малых выборок
        Sn = (6 * size * Dn + 1) / (6 * np.sqrt(size))
        chi_stats.append(Sn)
        
        # Сравниваем с критическими значениями
        for alpha, critical_value in Kolm_distrib.items():
            results[f"alpha = {alpha}"].append("H1" if Sn >= critical_value else "H0")
    
    # Создаём таблицу результатов
    results_df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(5)])
    results_tables[size] = results_df
    
    # Вывод результатов
    print(f"Results for n = {size}:\n")
    print(results_df)
    print("\n")

# Вывод значений статистики
for size, stats in results_tables.items():
    for i, stat in enumerate(chi_stats):
        print(f"n={size}, Sample {i + 1}: Sn = {np.round(stat, 3)}")
# Out:
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H1           H1           H0
# Sample 5          H0           H0           H0
#
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# Results for n = 200:
#
# ...

# %% [markdown]
# для n >= 20

# %%
# Заданное значение μ
mu = 22

sizes = samples_c.keys()

# Критические значения для Колмогорова
Kolm_distrib = {0.1: 1.22, 0.05: 1.36, 0.01: 1.63}

# Функция для оценки θ
def laplace_theta(sample, mu):
    return len(sample) / np.sum(np.abs(sample - mu))

# Функция распределения Лапласа
def laplace_cdf(x, mu, theta):
    if x < mu:
        return 0.5 * np.exp(theta * (x - mu))
    else:
        return 1 - 0.5 * np.exp(-theta * (x - mu))

# Применение критерия Колмогорова
results_tables = {}
for size in sizes:
    print(f"n = {size}\n")
    results = {f"alpha = {alpha}": [] for alpha in Kolm_distrib.keys()}
    loc_size = size // 2  # Разбиение выборки на две части
    for i in range(5):
        part1 = samples_c[size][i][:loc_size]
        part2 = samples_c[size][i][loc_size:]
        
        # Оценка θ по первой части
        theta = laplace_theta(part1, mu)
        
        # Проверка гипотезы на второй части
        sorted_sample = np.sort(part2)
        Dn_p = []
        Dn_m = []
        for k in range(1, loc_size + 1):
            F_empirical = k / loc_size
            F_theoretical = laplace_cdf(sorted_sample[k - 1], mu, theta)
            Dn_p.append(np.abs(F_empirical - F_theoretical))
            Dn_m.append(np.abs(F_theoretical - (k - 1) / loc_size))
        Dn = max(max(Dn_p), max(Dn_m))
        
        # Выбор статистики в зависимости от размера выборки
        if loc_size > 20:
            Sn = np.sqrt(loc_size) * Dn  # Для больших выборок
        else:
            Sn = (6 * loc_size * Dn + 1) / (6 * np.sqrt(loc_size))  # Для малых выборок
        
        # Сравнение с критическими значениями
        for alpha, critical_value in Kolm_distrib.items():
            results[f"alpha = {alpha}"].append("H1" if Sn >= critical_value else "H0")
    
    # Создаём таблицу результатов
    results_df = pd.DataFrame(results, index=[f"{i + 1}" for i in range(5)])
    results_tables[size] = results_df
    
    # Вывод результатов
    print(f"Results for n = {size}:\n")
    print(results_df)
    print("\n")
# Out:
# n = 5
#
# Results for n = 5:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H1           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H0           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 100
#
# Results for n = 100:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# 2          H1           H0           H0
# 3          H0           H0           H0
# 4          H0           H0           H0
# 5          H0           H0           H0
#
#
# n = 200
#
# Results for n = 200:
#
#   alpha = 0.1 alpha = 0.05 alpha = 0.01
# 1          H0           H0           H0
# ...

# %% [markdown]
# ## хи - квадрат для сложной

# %%
def compute_chi_square_statistics(alpha_levels, degrees_of_freedom):
    """
    Вычисление критических значений хи-квадрат для заданных уровней значимости и степеней свободы.
    
    :param alpha_levels: Список уровней значимости (например, [0.1, 0.05, 0.01]).
    :param degrees_of_freedom: Список степеней свободы (например, [1, 2, 3, ..., 10]).
    :return: Словарь критических значений хи-квадрат для каждой комбинации.
    """
    chi_square_values = {}
    
    for df in degrees_of_freedom:
        chi_square_values[df] = {}
        for alpha in alpha_levels:
            critical_value = chi2.ppf(1 - alpha, df)
            chi_square_values[df][f"alpha={alpha}"] = critical_value
    
    return chi_square_values

# Пример входных данных
alpha_levels = [0.1, 0.05, 0.01]  # Уровни значимости
degrees_of_freedom = [3-2,5-2,10-2]  # Степени свободы от 1 до 10

# Вычисляем критические значения
chi_square_results = compute_chi_square_statistics(alpha_levels, degrees_of_freedom)

# Выводим результаты в удобной таблице
import pandas as pd

chi_square_df = pd.DataFrame(chi_square_results).T  # Создаем DataFrame для вывода
print(chi_square_df)
# Out:
#    alpha=0.1  alpha=0.05  alpha=0.01
# 1   2.705543    3.841459    6.634897
# 3   6.251389    7.814728   11.344867
# 8  13.361566   15.507313   20.090235

# %%
# Параметры разбиения
N = 3  # Количество интервалов
bounds = [-np.inf, 21.95, 22.05, np.inf]  # Границы интервалов
sizes = list(samples_c.keys())  # Преобразуем ключи в список для индексирования

# Квантили хи-квадрат
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 2),
    0.05: chi2.ppf(1 - 0.05, df=N - 2),
    0.01: chi2.ppf(1 - 0.01, df=N - 2),
}

# Оценка параметра \(\hat{\theta}\) для каждой выборки
def estimate_theta(sample):
    """
    Оценка параметра \(\hat{\theta}\) для распределения Лапласа.
    """
    return len(sample) / np.sum(np.abs(sample - 22))  # Оценка \(\hat{\theta}\)

# Группировка выборок по интервалам
grouped_samples = {}
theta_estimates = {}  # Храним оценки параметра \(\hat{\theta}\)
for n in sizes:
    grouped_samples[n] = []
    theta_estimates[n] = []
    for sample in samples_c[n]:
        theta = estimate_theta(sample)  # Оценка параметра
        theta_estimates[n].append(theta)
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        theta = theta_estimates[n][i]  # Оценка параметра для конкретной выборки
        p_i = [
            0.5 * np.exp(theta * (bounds[1] - 22)),  # Вероятность для \(\Delta_1\)
            1 - np.exp(theta * (bounds[2] - 22)),   # Вероятность для \(\Delta_2\)
            0.5 * np.exp(-theta * (bounds[2] - 22))  # Вероятность для \(\Delta_3\)
        ]
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n * p_i[interval - 1]  # Ожидаемая частота
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Функция для применения критерия согласия хи-квадрат
def chi_square_test(chi_stats, critical_values):
    all_results = {}
    for n, stats in chi_stats.items():
        print(f"n = {n}\n")
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")
        
        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(len(stats))])
        all_results[n] = df
        print(f"Results for n = {n}:\n")
        print(df)
        print("\n")
    return all_results

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений хи-квадрат
for n, stats in chi_stats.items():
    for i, stat in enumerate(stats):
        print(f"n = {n}, Sample {i + 1}: χ² = {np.round(stat, 4)}")
# Out:
# n = 5
#
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 100
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# ...

# %%
# Параметры выборок
sizes = list(samples_c.keys())  # Размеры выборок
N = 3  # Количество равновероятных интервалов

# Квантили хи-квадрат для сложной гипотезы (\(df = N - 2\))
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 2),
    0.05: chi2.ppf(1 - 0.05, df=N - 2),
    0.01: chi2.ppf(1 - 0.01, df=N - 2),
}

# Оценка параметра \(\hat{\theta}\) для каждой выборки
def estimate_theta(sample):
    """
    Оценка параметра \(\hat{\theta}\) для распределения Лапласа.
    """
    return len(sample) / np.sum(np.abs(sample - 22))

# Генерация равновероятных интервалов
def compute_bounds(theta, mu, N):
    """
    Вычисляет границы равновероятных интервалов для распределения Лапласа.
    """
    bounds = [-np.inf]
    for k in range(1, N):
        # Ищем значение квантиля, соответствующего вероятности k/N
        p = k / N
        if p <= 0.5:
            bounds.append(mu + np.log(2 * p) / theta)
        else:
            bounds.append(mu - np.log(2 * (1 - p)) / theta)
    bounds.append(np.inf)
    return bounds

# Группировка выборок по интервалам
grouped_samples = {}
theta_estimates = {}  # Оценки \(\hat{\theta}\) для каждой выборки
interval_bounds = {}  # Границы интервалов
for n in sizes:
    grouped_samples[n] = []
    theta_estimates[n] = []
    interval_bounds[n] = []
    for sample in samples_c[n]:
        theta = estimate_theta(sample)  # Оценка параметра
        theta_estimates[n].append(theta)
        bounds = compute_bounds(theta, mu=22, N=N)  # Границы интервалов
        interval_bounds[n].append(bounds)
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        theta = theta_estimates[n][i]  # Оценка параметра для конкретной выборки
        bounds = interval_bounds[n][i]
        # Вычисляем вероятности для каждого интервала
        p_i = []
        for k in range(1, N + 1):
            if k == 1:
                p_i.append(0.5 * np.exp(theta * (bounds[k] - 22)))
            elif k == N:
                p_i.append(0.5 * np.exp(-theta * (bounds[k - 1] - 22)))
            else:
                p_i.append(0.5 * (np.exp(theta * (bounds[k] - 22)) - np.exp(theta * (bounds[k - 1] - 22))))
        # Вычисляем статистику хи-квадрат
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n * p_i[interval - 1]
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Функция для применения критерия согласия хи-квадрат
def chi_square_test(chi_stats, critical_values):
    all_results = {}
    for n, stats in chi_stats.items():
        print(f"n = {n}\n")
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")
        
        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(len(stats))])
        all_results[n] = df
        print(f"Results for n = {n}:\n")
        print(df)
        print("\n")
    return all_results

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений хи-квадрат
for n, stats in chi_stats.items():
    for i, stat in enumerate(stats):
        print(f"n = {n}, Sample {i + 1}: χ² = {np.round(stat, 4)}")
# Out:
# n = 5
#
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H1           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 100
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H1           H1           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# ...

# %%
# Параметры выборок
sizes = list(samples_c.keys())  # Размеры выборок
N = 5  # Количество равновероятных интервалов

# Квантили хи-квадрат для сложной гипотезы (\(df = N - 2\))
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 2),
    0.05: chi2.ppf(1 - 0.05, df=N - 2),
    0.01: chi2.ppf(1 - 0.01, df=N - 2),
}

# Оценка параметра \(\hat{\theta}\) для каждой выборки
def estimate_theta(sample):
    """
    Оценка параметра \(\hat{\theta}\) для распределения Лапласа.
    """
    return len(sample) / np.sum(np.abs(sample - 22))

# Генерация равновероятных интервалов
def compute_bounds(theta, mu, N):
    """
    Вычисляет границы равновероятных интервалов для распределения Лапласа.
    """
    bounds = [-np.inf]
    for k in range(1, N):
        # Ищем значение квантиля, соответствующего вероятности k/N
        p = k / N
        if p <= 0.5:
            bounds.append(mu + np.log(2 * p) / theta)
        else:
            bounds.append(mu - np.log(2 * (1 - p)) / theta)
    bounds.append(np.inf)
    return bounds

# Группировка выборок по интервалам
grouped_samples = {}
theta_estimates = {}  # Оценки \(\hat{\theta}\) для каждой выборки
interval_bounds = {}  # Границы интервалов
for n in sizes:
    grouped_samples[n] = []
    theta_estimates[n] = []
    interval_bounds[n] = []
    for sample in samples_c[n]:
        theta = estimate_theta(sample)  # Оценка параметра
        theta_estimates[n].append(theta)
        bounds = compute_bounds(theta, mu=22, N=N)  # Границы интервалов
        interval_bounds[n].append(bounds)
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        theta = theta_estimates[n][i]  # Оценка параметра для конкретной выборки
        bounds = interval_bounds[n][i]
        # Вычисляем вероятности для каждого интервала
        p_i = []
        for k in range(1, N + 1):
            if k == 1:
                p_i.append(0.5 * np.exp(theta * (bounds[k] - 22)))
            elif k == N:
                p_i.append(0.5 * np.exp(-theta * (bounds[k - 1] - 22)))
            else:
                p_i.append(0.5 * (np.exp(theta * (bounds[k] - 22)) - np.exp(theta * (bounds[k - 1] - 22))))
        # Вычисляем статистику хи-квадрат
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n * p_i[interval - 1]
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Функция для применения критерия согласия хи-квадрат
def chi_square_test(chi_stats, critical_values):
    all_results = {}
    for n, stats in chi_stats.items():
        print(f"n = {n}\n")
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")
        
        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(len(stats))])
        all_results[n] = df
        print(f"Results for n = {n}:\n")
        print(df)
        print("\n")
    return all_results

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений хи-квадрат
for n, stats in chi_stats.items():
    for i, stat in enumerate(stats):
        print(f"n = {n}, Sample {i + 1}: χ² = {np.round(stat, 4)}")
# Out:
# n = 5
#
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H0           H0           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H1           H0           H0
# Sample 5          H1           H1           H0
#
#
# n = 100
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H1           H1           H1
# Sample 2          H1           H1           H1
# Sample 3          H1           H1           H1
# Sample 4          H1           H1           H1
# Sample 5          H1           H1           H1
#
#
# ...

# %%
# Параметры выборок
sizes = list(samples_c.keys())  # Размеры выборок
N = 10  # Количество равновероятных интервалов

# Квантили хи-квадрат для сложной гипотезы (\(df = N - 2\))
critical_values = {
    0.1: chi2.ppf(1 - 0.1, df=N - 2),
    0.05: chi2.ppf(1 - 0.05, df=N - 2),
    0.01: chi2.ppf(1 - 0.01, df=N - 2),
}

# Оценка параметра \(\hat{\theta}\) для каждой выборки
def estimate_theta(sample):
    """
    Оценка параметра \(\hat{\theta}\) для распределения Лапласа.
    """
    return len(sample) / np.sum(np.abs(sample - 22))

# Генерация равновероятных интервалов
def compute_bounds(theta, mu, N):
    """
    Вычисляет границы равновероятных интервалов для распределения Лапласа.
    """
    bounds = [-np.inf]
    for k in range(1, N):
        # Ищем значение квантиля, соответствующего вероятности k/N
        p = k / N
        if p <= 0.5:
            bounds.append(mu + np.log(2 * p) / theta)
        else:
            bounds.append(mu - np.log(2 * (1 - p)) / theta)
    bounds.append(np.inf)
    return bounds

# Группировка выборок по интервалам
grouped_samples = {}
theta_estimates = {}  # Оценки \(\hat{\theta}\) для каждой выборки
interval_bounds = {}  # Границы интервалов
for n in sizes:
    grouped_samples[n] = []
    theta_estimates[n] = []
    interval_bounds[n] = []
    for sample in samples_c[n]:
        theta = estimate_theta(sample)  # Оценка параметра
        theta_estimates[n].append(theta)
        bounds = compute_bounds(theta, mu=22, N=N)  # Границы интервалов
        interval_bounds[n].append(bounds)
        grouped_sample = np.digitize(sample, bins=bounds)  # Индексация интервалов
        grouped_samples[n].append(grouped_sample)

# Подсчёт частот
freq_vector = {}
for n in sizes:
    freq_vector[n] = [Counter(sample) for sample in grouped_samples[n]]

# Вычисление статистики хи-квадрат
chi_stats = {}
for n in sizes:
    chi_stats[n] = []
    for i in range(5):
        stat = 0
        theta = theta_estimates[n][i]  # Оценка параметра для конкретной выборки
        bounds = interval_bounds[n][i]
        # Вычисляем вероятности для каждого интервала
        p_i = []
        for k in range(1, N + 1):
            if k == 1:
                p_i.append(0.5 * np.exp(theta * (bounds[k] - 22)))
            elif k == N:
                p_i.append(0.5 * np.exp(-theta * (bounds[k - 1] - 22)))
            else:
                p_i.append(0.5 * (np.exp(theta * (bounds[k] - 22)) - np.exp(theta * (bounds[k - 1] - 22))))
        # Вычисляем статистику хи-квадрат
        for interval in range(1, N + 1):
            observed = freq_vector[n][i][interval] if interval in freq_vector[n][i] else 0
            expected = n * p_i[interval - 1]
            stat += (observed - expected) ** 2 / expected
        chi_stats[n].append(stat)

# Функция для применения критерия согласия хи-квадрат
def chi_square_test(chi_stats, critical_values):
    all_results = {}
    for n, stats in chi_stats.items():
        print(f"n = {n}\n")
        results = {f"alpha = {alpha}": [] for alpha in critical_values.keys()}
        for stat in stats:
            for alpha, critical in critical_values.items():
                results[f"alpha = {alpha}"].append("H1" if stat >= critical else "H0")
        
        # Создание таблицы результатов
        df = pd.DataFrame(results, index=[f"Sample {i + 1}" for i in range(len(stats))])
        all_results[n] = df
        print(f"Results for n = {n}:\n")
        print(df)
        print("\n")
    return all_results

# Запуск теста
results_tables = chi_square_test(chi_stats, critical_values)

# Вывод значений хи-квадрат
for n, stats in chi_stats.items():
    for i, stat in enumerate(stats):
        print(f"n = {n}, Sample {i + 1}: χ² = {np.round(stat, 4)}")
# Out:
# n = 5
#
# Results for n = 5:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H1           H1           H0
# Sample 2          H0           H0           H0
# Sample 3          H0           H0           H0
# Sample 4          H0           H0           H0
# Sample 5          H0           H0           H0
#
#
# n = 10
#
# Results for n = 10:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H1           H1           H1
# Sample 2          H1           H1           H0
# Sample 3          H1           H1           H0
# Sample 4          H1           H1           H1
# Sample 5          H1           H1           H1
#
#
# n = 100
#
# Results for n = 100:
#
#          alpha = 0.1 alpha = 0.05 alpha = 0.01
# Sample 1          H1           H1           H1
# Sample 2          H1           H1           H1
# Sample 3          H1           H1           H1
# Sample 4          H1           H1           H1
# Sample 5          H1           H1           H1
#
#
# ...

# %% [markdown]
# ## Критерий однородности

# %%
# Уровень значимости
alpha = 0.05
lambda_alpha = 1.36  # Значение λ_α для уровня значимости α = 0.05

# Функция для вычисления эмпирической функции распределения
def empirical_cdf(sample, x):
    return np.sum(sample <= x) / len(sample)

# Функция для вычисления статистики D_{n,m}
def compute_statistic(sample1, sample2):
    combined_sample = np.sort(np.concatenate([sample1, sample2]))
    d_nm = max(
        abs(empirical_cdf(sample1, x) - empirical_cdf(sample2, x))
        for x in combined_sample
    )
    return d_nm

# Функция для проверки гипотезы однородности
def test_hypothesis(samples, alpha, lambda_alpha):
    results = {}
    for n1, group1 in samples.items():
        for n2, group2 in samples.items():
            if n1 == n2:
                continue
            key = f"n1 = {n1}, n2 = {n2}"
            results[key] = []
            for i in range(len(group1)):
                for j in range(len(group2)):
                    sample1 = group1[i]
                    sample2 = group2[j]
                    d_nm = compute_statistic(sample1, sample2)
                    t_alpha = lambda_alpha * np.sqrt((1 / len(sample1)) + (1 / len(sample2)))
                    reject_h0 = d_nm <= t_alpha
                    results[key].append({
                        "Пара выборок": f"Выборка {i + 1} vs Выборка {j + 1}",
                        "D_nm": d_nm,
                        "t_alpha": t_alpha,
                        "Принимаем H0": reject_h0
                    })
    return results


# Выполнение теста
results = test_hypothesis(samples_c, alpha, lambda_alpha)

# Вывод результатов
for key, result in results.items():
    print(f"Результаты для {key}:\n")
    df = pd.DataFrame(result)
    print(df)
    print("\n")
# Out:
# Результаты для n1 = 5, n2 = 10:
#
#               Пара выборок  D_nm   t_alpha  Принимаем H0
# 0   Выборка 1 vs Выборка 1   0.4  0.744903          True
# 1   Выборка 1 vs Выборка 2   0.5  0.744903          True
# 2   Выборка 1 vs Выборка 3   0.3  0.744903          True
# 3   Выборка 1 vs Выборка 4   0.5  0.744903          True
# 4   Выборка 1 vs Выборка 5   0.4  0.744903          True
# 5   Выборка 2 vs Выборка 1   0.3  0.744903          True
# 6   Выборка 2 vs Выборка 2   0.3  0.744903          True
# 7   Выборка 2 vs Выборка 3   0.3  0.744903          True
# 8   Выборка 2 vs Выборка 4   0.5  0.744903          True
# 9   Выборка 2 vs Выборка 5   0.3  0.744903          True
# 10  Выборка 3 vs Выборка 1   0.6  0.744903          True
# 11  Выборка 3 vs Выборка 2   0.7  0.744903          True
# 12  Выборка 3 vs Выборка 3   0.4  0.744903          True
# 13  Выборка 3 vs Выборка 4   0.3  0.744903          True
# 14  Выборка 3 vs Выборка 5   0.4  0.744903          True
# ...

# %% [markdown]
# # материал

# %%
# Функция отношения правдоподобия для распределения Лапласа
def likelihood_ratio_laplace(theta1, theta0, sample):
    n = len(sample)
    T = np.mean(np.abs(sample - np.median(sample)))
    return np.exp(-n * (theta1 - theta0) / theta1 * T - n * (np.log(theta1) - np.log(theta0)))

# Вычисление t_alpha по alpha
def t(alpha):
    return -sci_norm.ppf(alpha)  # квантиль стандартного нормального распределения

# Критерий Неймана-Пирсона
def criterion_laplace(theta0, theta1, alpha, sample):
    n = len(sample)
    T = np.mean(np.abs(sample - np.median(sample)))
    stat = np.sqrt(n) * theta1 * (T - 1 / theta1)
    if stat >= t(alpha):
        print("Верна альтернативная гипотеза")
    else:
        print("Верна основная гипотеза")

# Ошибка второго рода для распределения Лапласа
def find_beta_laplace(theta0, theta1, alpha, n):
    return sci_norm.cdf(t(alpha) - np.sqrt(n) * (theta1 - theta0) / theta1)

# Минимальное количество материала для распределения Лапласа
def find_n_laplace(theta0, theta1, alpha, beta):
    norm = sci_norm()
    return int(np.ceil(theta1**2 / (theta1 - theta0)**2 * (norm.ppf(alpha) + norm.ppf(beta))**2))

# Проверка кода
theta0 = 1.0
theta1 = 2.0
alpha = 0.05
beta = 0.01

# Генерация выборки
np.random.seed(42)
sample = np.random.laplace(loc=0, scale=1 / theta1, size=100)

# Функция отношения правдоподобия
print("Likelihood ratio:", likelihood_ratio_laplace(theta1, theta0, sample))

# Проверка критерия
criterion_laplace(theta0, theta1, alpha, sample)

# Подсчет минимального количества материала
n_min = find_n_laplace(theta0, theta1, alpha, beta)
print(f"Минимальное количество материала: n = {n_min}")

# Проверка ошибки второго рода
print("Ошибка второго рода (beta):", find_beta_laplace(theta0, theta1, alpha, n_min))
#print("Ошибка второго рода (beta, n-1):", find_beta_laplace(theta0, theta1, alpha, n_min - 1))
# Out:
# Likelihood ratio: 5.835497901415177e-42
# Верна основная гипотеза
# Минимальное количество материала: n = 64
# Ошибка второго рода (beta): 0.009257705373495398
